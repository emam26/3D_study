# %% [markdown]
# # Batch visualization overview
#
# This notebook does not recompute representations. It assembles the already-generated panels for all 10 NYUv2 and 10 SUN RGB-D samples into one overview image per sample.

# %%
from pathlib import Path
if not (Path.cwd() / "repstudy").exists():
    raise RuntimeError("Open this notebook with the study repository as the Jupyter working directory")

from repstudy.make_overviews import make_overviews

created = make_overviews("outputs")
print(f"Created {len(created)} overview images")
for path in created:
    print(path)
